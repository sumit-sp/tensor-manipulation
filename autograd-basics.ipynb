# %%
import warnings
from IPython.display import display

warnings.filterwarnings("ignore")

# %%
from transformers import pipeline, set_seed
from datasets import load_dataset

# %%
generator = pipeline('text-generation', model='gpt2')
set_seed(42)
generator("Hello, I'm a language model,", max_length=30, num_return_sequences=5)

# %% [markdown]
# #### Pipeline for,
# ##### Get basic prompt from user --> add context using text generation model --> feed updated prompt to image generator

# %%
context_generator = pipeline("text-generation", model="openai-community/gpt2")

# %%
context_generator("Elaborate the sentence following this sentence./n A couple seating on a beach", max_length = 50)

# %%
from diffusers import DiffusionPipeline

pipeline = DiffusionPipeline.from_pretrained("stabilityai/stable-diffusion-xl-base-1.0")

# %%
# %matplotlib inline

# %%
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = torch.linspace(0.0, 2*torch.pi, 16, requires_grad = True)

# a = torch.sin(x).clone().detach().requires_grad_(True)
a = torch.sin(x)
a.retain_grad()
plt.plot(x.detach().numpy(), a.detach().numpy())
plt.show()

b = 3*a + 10
b
# Out:
# tensor([10.0000, 11.2202, 12.2294, 12.8532, 12.9836, 12.5981, 11.7634, 10.6237,
#          9.3763,  8.2366,  7.4019,  7.0164,  7.1468,  7.7706,  8.7798, 10.0000],
#        grad_fn=<AddBackward0>)

# %%
ext = torch.ones_like( b)

# %%
b.backward(torch.ones_like(b))

# %%
b.sum().backward()

# %%
a.grad
# Out:
# tensor([3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3., 3.])

# %%
x.grad
# Out:
# tensor([ 3.0000,  2.7406,  2.0074,  0.9271, -0.3136, -1.5000, -2.4271, -2.9344,
#         -2.9344, -2.4271, -1.5000, -0.3136,  0.9271,  2.0074,  2.7406,  3.0000])

# %%
plt.plot(x.detach().numpy(), x.grad)

# %%
a.grad_fn
